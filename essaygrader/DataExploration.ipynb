# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
df = pd.read_feather('dataset.feather')
df.columns

# essay_id: A unique identifier for each individual student essay
# essay_set: 1-8, an id for each set of essays
# essay: The ascii text of a student's response
# rater1_domain1: Rater 1's domain 1 score; all essays have this
# rater2_domain1: Rater 2's domain 1 score; all essays have this
# rater3_domain1: Rater 3's domain 1 score; only some essays in set 8 have this.
# domain1_score: Resolved score between the raters; all essays have this
# rater1_domain2: Rater 1's domain 2 score; only essays in set 2 have this
# rater2_domain2: Rater 2's domain 2 score; only essays in set 2 have this
# domain2_score: Resolved score between the raters; only essays in set 2 have this
# rater1_trait1 score - rater3_trait6 score: trait scores for sets 7-8
# Out:
# Index(['essay_id', 'essay_set', 'grade', 'Source Dependent Responses',
#        'Persuasive/Narrative/Expository', 'essay', 'cleaned_essay2',
#        'cleaned_essay2_no_sw', 'prompt', 'Average Word Length', 'misspelled',
#        'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
#        'vocabulary', 'score', 'percent_stop_words', 'normalized_score'],
#       dtype='object')

# %%
from process.misspellings import nmisspelled

df['percent_misspelled'] = df['cleaned_essay2'].apply(nmisspelled)

# %%
from process.keywords import keyWords
df['percent_key_words'] = df.apply(lambda x: keyWords(x.prompt, x.cleaned_essay2), axis=1)
df['percent_key_words']
# Out:
# 0        2.61
# 1        2.66
# 2        6.16
# 3        4.50
# 4        3.20
#          ...
# 12971    1.11
# 12972    0.95
# 12973    0.64
# 12974    1.08
# 12975    0.43
# Name: percent_key_words, Length: 12976, dtype: float64

# %%
def normalize_imagery_score(essayLength, score):
    return score/essayLength

df['normalize_imagery_score'] = df.apply(lambda x: normalize_imagery_score(x.word_count, x.score), axis=1)
df['normalize_imagery_score']
# Out:
# 0        0.413820
# 1        0.472271
# 2        0.486248
# 3        0.483008
# 4        0.381553
#            ...
# 12971    0.388674
# 12972    0.404485
# 12973    0.269426
# 12974    0.314107
# 12975    0.394017
# Name: normalize_imagery_score, Length: 12976, dtype: float64

# %%
df = df.drop(['misspelled'], axis=1)

# %%
df.columns
# Out:
# Index(['essay_id', 'essay_set', 'grade', 'Source Dependent Responses',
#        'Persuasive/Narrative/Expository', 'essay', 'cleaned_essay2',
#        'cleaned_essay2_no_sw', 'prompt', 'Average Word Length', 'misspelled',
#        'word_count', 'average_sentence_length', 'percent_key_words',
#        'sentcount', 'vocabulary', 'score', 'percent_stop_words',
#        'normalized_score', 'percent_misspelled'],
#       dtype='object')

# %%
df.hist(figsize=(20, 20))
# Out:
# array([[<AxesSubplot:title={'center':'essay_id'}>,
#         <AxesSubplot:title={'center':'essay_set'}>,
#         <AxesSubplot:title={'center':'grade'}>,
#         <AxesSubplot:title={'center':'Source Dependent Responses'}>],
#        [<AxesSubplot:title={'center':'Persuasive/Narrative/Expository'}>,
#         <AxesSubplot:title={'center':'Average Word Length'}>,
#         <AxesSubplot:title={'center':'misspelled'}>,
#         <AxesSubplot:title={'center':'word_count'}>],
#        [<AxesSubplot:title={'center':'average_sentence_length'}>,
#         <AxesSubplot:title={'center':'key_words_count'}>,
#         <AxesSubplot:title={'center':'sentcount'}>,
#         <AxesSubplot:title={'center':'vocabulary'}>],
#        [<AxesSubplot:title={'center':'score'}>,
#         <AxesSubplot:title={'center':'percent_stop_words'}>,
#         <AxesSubplot:title={'center':'normalized_score'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Looking at distributions of essay scores based on essay sets

# %%
# Looking at number of essays from each set (8 essay sets)
df['essay_set'].value_counts()
# Out:
# 5    1805
# 6    1800
# 2    1800
# 1    1783
# 4    1770
# 3    1726
# 7    1569
# 8     723
# Name: essay_set, dtype: int64

# %%
# Separating essay sets
essay_set_1 = df.loc[df['essay_set'] == 1]
essay_set_2 = df.loc[df['essay_set'] == 2]
essay_set_3 = df.loc[df['essay_set'] == 3]
essay_set_4 = df.loc[df['essay_set'] == 4]
essay_set_5 = df.loc[df['essay_set'] == 5]
essay_set_6 = df.loc[df['essay_set'] == 6]
essay_set_7 = df.loc[df['essay_set'] == 7]
essay_set_8 = df.loc[df['essay_set'] == 8]

# %%
scores1 = essay_set_1['domain1_score'].values
scores2 = essay_set_2['domain1_score'].values
scores3 = essay_set_3['domain1_score'].values
scores4 = essay_set_4['domain1_score'].values
scores5 = essay_set_5['domain1_score'].values
scores6 = essay_set_6['domain1_score'].values
scores7 = essay_set_7['domain1_score'].values
scores8 = essay_set_8['domain1_score'].values

# create a histogram of scores
fig, ax = plt.subplots(8, figsize=(20, 45))
ax[0].hist(scores1)
ax[1].hist(scores2)
ax[2].hist(scores3)
ax[3].hist(scores4)
ax[4].hist(scores5)
ax[5].hist(scores6)
ax[6].hist(scores7)
ax[7].hist(scores8)

# title the graph
for i in range(8):
  ax[i].set_title('Distribution of Scores for Essay Set ' + str(i+1))

# label the x and y axes
for i in range(8):
  ax[i].set_xlabel('Score')
  ax[i].set_ylabel('Frequency')
  # logarithmic scale on the y axis
  ax[i].set_yscale('log')
fig.savefig('images/scoreDistribution.svg')

# %%
scores = [scores1, scores2, scores3, scores4, scores5, scores6, scores7, scores8]
for i in range(len(scores)):
  print("Largest score of Essay Set " + str(i+1) + ": " + str(max(scores[i])))
  print("Smallest score of Essay Set " + str(i+1) + ": " + str(min(scores[i])))
  print('\n')
# Out:
# Largest score of Essay Set 1: 12
# Smallest score of Essay Set 1: 2
#
#
# Largest score of Essay Set 2: 6
# Smallest score of Essay Set 2: 1
#
#
# Largest score of Essay Set 3: 3
# Smallest score of Essay Set 3: 0
#
#
# Largest score of Essay Set 4: 3
# Smallest score of Essay Set 4: 0
#
#
# Largest score of Essay Set 5: 4
# Smallest score of Essay Set 5: 0
#
#
# Largest score of Essay Set 6: 4
# Smallest score of Essay Set 6: 0
#
#
# Largest score of Essay Set 7: 24
# Smallest score of Essay Set 7: 2
#
#
# Largest score of Essay Set 8: 60
# Smallest score of Essay Set 8: 10

# %% [markdown]
# Correlation Analysis/Feature Selection

# %%
# All essay sets
prelim = df[['Average Word Length', 'misspelled',
       'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
       'vocabulary', 'score', 'percent_stop_words', 'percent_misspelled', 'percent_key_words',      'normalize_imagery_score', 'normalized_score']]
corr = prelim.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
df = df.drop(['percent_key_words', 'normalize_imagery_score'], axis=1)
df.columns
# Out:
# Index(['essay_id', 'essay_set', 'grade', 'Source Dependent Responses',
#        'Persuasive/Narrative/Expository', 'essay', 'cleaned_essay2',
#        'cleaned_essay2_no_sw', 'prompt', 'Average Word Length', 'misspelled',
#        'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
#        'vocabulary', 'score', 'percent_stop_words', 'normalized_score',
#        'percent_misspelled'],
#       dtype='object')

# %%
df = df.rename(columns={'key_words_count': 'percent_key_words'})
df.columns
# Out:
# Index(['essay_id', 'essay_set', 'grade', 'Source Dependent Responses',
#        'Persuasive/Narrative/Expository', 'essay', 'cleaned_essay2',
#        'cleaned_essay2_no_sw', 'prompt', 'Average Word Length', 'misspelled',
#        'word_count', 'average_sentence_length', 'percent_key_words',
#        'sentcount', 'vocabulary', 'score', 'percent_stop_words',
#        'normalized_score', 'percent_misspelled'],
#       dtype='object')

# %%
# Middle school essays
middle_school = df.loc[df['grade'] == 0]
prelimMS = middle_school[['Average Word Length', 'misspelled',
       'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
       'vocabulary', 'score', 'percent_stop_words', 'percent_misspelled','percent_key_words',      'normalize_imagery_score', 'normalized_score']]
corr = prelimMS.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
# High School Essays
high_school = df.loc[df['grade'] == 1]
prelimHS = high_school[['Average Word Length', 'misspelled',
       'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
       'vocabulary', 'score', 'percent_stop_words', 'percent_misspelled','percent_key_words',      'normalize_imagery_score', 'normalized_score']]
corr = prelimHS.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
# Source Dependent Responses Essays
source = df.loc[df['Source Dependent Responses'] == 1]
prelimSource = source[['Average Word Length', 'misspelled',
       'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
       'vocabulary', 'score', 'percent_stop_words', 'percent_misspelled','percent_key_words',      'normalize_imagery_score', 'normalized_score']]
corr = prelimSource.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
# Persuasive/Narrative/Expository Essays
pne = df.loc[df['Persuasive/Narrative/Expository'] == 1]
prelimPNE = pne[['Average Word Length', 'misspelled',
       'word_count', 'average_sentence_length', 'key_words_count', 'sentcount',
       'vocabulary', 'score', 'percent_stop_words', 'percent_misspelled','percent_key_words',      'normalize_imagery_score', 'normalized_score']]
corr = prelimPNE.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Old Preliminary Results

# %%
prelim1 = essay_set_1[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim1.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim2 = essay_set_2[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim2.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim3 = essay_set_3[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim3.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim4 = essay_set_4[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim4.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim5 = essay_set_5[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim5.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim6 = essay_set_6[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim6.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim7 = essay_set_7[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim7.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
prelim8 = essay_set_8[['Average Word Length', 'misspelled', 'word_count', 'average_sentence_length', 'key_words_count', 'sentcount', 'normalized_score']]
corr = prelim8.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>
